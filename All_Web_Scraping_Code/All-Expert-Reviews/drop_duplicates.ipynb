# %%
import pandas as pd

# %%
data=pd.read_csv('Expert_Reviews_For _New_Products - expert_reviews_91mobiles.csv')

# %%
len(data)
# Out:
# 153

# %%
temp=data.drop_duplicates('product_id',keep='first')

# %%
len(temp)
# Out:
# 54

# %%
temp
# Out:
#      product_id  source_id  source_product_id  overall_rating  outof_rating  \
# 0          1720         30              29053             NaN           NaN
# 1          1721         30              29780             4.0           5.0
# 2          2272         30              33000             NaN           NaN
# 4          2273         30              20262             NaN           NaN
# 5          2244         30              32425             NaN           NaN
# 8          1684         30              28880             NaN           NaN
# 9          2457         30              33597             3.5           5.0
# 19         2256         30              32288             3.0           5.0
# 25         2212         30              31534             4.0           5.0
# 29         1965         30              30193             3.5           5.0
# 31         2229         30              32063             NaN           NaN
# ...

# %%
temp.to_csv('expert_reviews_91mobiles.csv',encoding='utf-8')
